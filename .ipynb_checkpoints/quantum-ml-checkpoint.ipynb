# %%
# !pip install qiskit
# Out:
# Collecting qiskit
#   Downloading https://files.pythonhosted.org/packages/59/2d/563ea183a9462f1300e861796535405d0fca8616b6db849488eac225893b/qiskit-0.14.0.tar.gz
# Collecting qiskit-terra==0.11.0
#   Downloading https://files.pythonhosted.org/packages/30/e4/89f66e07d63d9cf1d912b39dc044c3c37673a3b644c8c6e243ca57ba72ef/qiskit_terra-0.11.0-cp36-cp36m-manylinux1_x86_64.whl (2.7MB)
#      |████████████████████████████████| 2.7MB 2.6MB/s eta 0:00:01     |████████████▊                   | 1.1MB 2.6MB/s eta 0:00:01
# Collecting qiskit-aer==0.3.4
#   Downloading https://files.pythonhosted.org/packages/bf/31/b7064395c744e759a1c20ca81e806752f9859bb604fef254a599d66a521d/qiskit_aer-0.3.4-cp36-cp36m-manylinux2010_x86_64.whl (18.2MB)
#      |████████████████████████████████| 18.2MB 36kB/s  eta 0:00:01     |████████████████████▉           | 11.9MB 9.8MB/s eta 0:00:01     |██████████████████████▏         | 12.6MB 9.8MB/s eta 0:00:01
# Collecting qiskit-ibmq-provider==0.4.4
#   Downloading https://files.pythonhosted.org/packages/7f/91/1236cd0da9552744aae173792c44a7a1611436f3a8156b62604aab2e67e5/qiskit_ibmq_provider-0.4.4-py3-none-any.whl (89kB)
#      |████████████████████████████████| 92kB 809kB/s  eta 0:00:01
# Collecting qiskit-ignis==0.2.0
#   Downloading https://files.pythonhosted.org/packages/78/f2/f4f89c65d2c13f473092f7e800519836611ddeeaab8d4591a70555b26a37/qiskit_ignis-0.2.0-py3-none-any.whl (100kB)
#      |████████████████████████████████| 102kB 1.2MB/s eta 0:00:01
# Collecting qiskit-aqua==0.6.1
#   Downloading https://files.pythonhosted.org/packages/47/2b/632c195974804d17dca01554caa013dd0c3023f4e4e6b91213c3381ce514/qiskit_aqua-0.6.1-py3-none-any.whl (979kB)
#      |████████████████████████████████| 983kB 25.9MB/s eta 0:00:01
# Requirement already satisfied: dill>=0.3 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from qiskit-terra==0.11.0->qiskit) (0.3.1.1)
# Collecting marshmallow<4,>=3
#   Downloading https://files.pythonhosted.org/packages/6e/76/01224f14737627166b94eb3bf0e334372c014edca781e39db320ce977755/marshmallow-3.3.0-py2.py3-none-any.whl (45kB)
#      |████████████████████████████████| 51kB 554kB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.13 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from qiskit-terra==0.11.0->qiskit) (1.16.2)
# Requirement already satisfied: scipy>=1.0 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from qiskit-terra==0.11.0->qiskit) (1.1.0)
# Requirement already satisfied: networkx>=2.2; python_version > "3.5" in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from qiskit-terra==0.11.0->qiskit) (2.2)
# Collecting marshmallow-polyfield<6,>=5.7
#   Downloading https://files.pythonhosted.org/packages/d7/6c/416e7e529d03362bb57bb4be16a0bb1ada6325b12adf3e31fec4c10ef1b1/marshmallow-polyfield-5.7.tar.gz
# Requirement already satisfied: sympy>=1.3 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from qiskit-terra==0.11.0->qiskit) (1.3)
# Requirement already satisfied: jsonschema>=2.6 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from qiskit-terra==0.11.0->qiskit) (2.6.0)
# Requirement already satisfied: ply>=3.10 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from qiskit-terra==0.11.0->qiskit) (3.11)
# Requirement already satisfied: psutil>=5 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from qiskit-terra==0.11.0->qiskit) (5.4.7)
# Requirement already satisfied: requests>=2.19 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from qiskit-ibmq-provider==0.4.4->qiskit) (2.22.0)
# Collecting websockets<8,>=7
#   Downloading https://files.pythonhosted.org/packages/43/71/8bfa882b9c502c36e5c9ef6732969533670d2b039cbf95a82ced8f762b80/websockets-7.0-cp36-cp36m-manylinux1_x86_64.whl (63kB)
#      |████████████████████████████████| 71kB 779kB/s  eta 0:00:01
# Collecting nest-asyncio!=1.1.0,>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/52/01/55100e0dda328f2181b719bddc5af0a24487de81038747d676d5be7ef879/nest_asyncio-1.2.1-py3-none-any.whl
# Collecting requests-ntlm>=1.1.0
#   Downloading https://files.pythonhosted.org/packages/03/4b/8b9a1afde8072c4d5710d9fa91433d504325821b038e00237dc8d6d833dc/requests_ntlm-1.1.0-py2.py3-none-any.whl
# Requirement already satisfied: setuptools>=40.1.0 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from qiskit-ignis==0.2.0->qiskit) (41.6.0)
# Collecting docplex
#   Downloading https://files.pythonhosted.org/packages/1c/06/de7833f2e70d51286611a2676f130f0978d2c16f65047cb965d0af579d08/docplex-2.12.182.tar.gz (565kB)
#      |████████████████████████████████| 573kB 31.5MB/s eta 0:00:01
# Collecting fastdtw
#   Downloading https://files.pythonhosted.org/packages/99/43/30f2d8db076f216b15c10db663b46e22d1750b1ebacd7af6e62b83d6ab98/fastdtw-0.3.4.tar.gz (133kB)
#      |████████████████████████████████| 143kB 26.3MB/s eta 0:00:01
# Collecting dlx
#   Downloading https://files.pythonhosted.org/packages/54/c0/b8fb5bb727e983b6f5251433ef941b48f38c65bb0bd6ec509e9185bcd406/dlx-1.0.4.tar.gz
# Collecting cvxopt
#   Downloading https://files.pythonhosted.org/packages/98/54/f54833cd7d76212353f852e6daeb2c1150a0337a0de0c201f9f084da9219/cvxopt-1.2.3-cp36-cp36m-manylinux1_x86_64.whl (11.6MB)
#      |████████████████████████████████| 11.6MB 175kB/s eta 0:00:01
# Collecting pyscf; sys_platform != "win32"
#   Downloading https://files.pythonhosted.org/packages/22/37/c9ed47f2b3f92a4f6955ab5454bf364cee6c05edb40e35b31b21b56d39f4/pyscf-1.7.0-cp36-cp36m-manylinux1_x86_64.whl (24.3MB)
#      |████████████████████████████████| 24.3MB 27kB/s s eta 0:00:01    |██████▎                         | 4.8MB 10.4MB/s eta 0:00:02.4MB/s eta 0:00:02█████████████████         | 17.4MB 5.8MB/s eta 0:00:02   |███████████████████████████▏    | 20.6MB 5.8MB/s eta 0:00:01
# Requirement already satisfied: h5py in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from qiskit-aqua==0.6.1->qiskit) (2.8.0)
# Collecting quandl
#   Downloading https://files.pythonhosted.org/packages/07/ab/8cd479fba8a9b197a43a0d55dd534b066fb8e5a0a04b5c0384cbc5d663aa/Quandl-3.5.0-py2.py3-none-any.whl
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from qiskit-aqua==0.6.1->qiskit) (0.20.3)
# Requirement already satisfied: decorator>=4.3.0 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from networkx>=2.2; python_version > "3.5"->qiskit-terra==0.11.0->qiskit) (4.3.0)
# Requirement already satisfied: six in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from marshmallow-polyfield<6,>=5.7->qiskit-terra==0.11.0->qiskit) (1.11.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.4.4->qiskit) (2.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.4.4->qiskit) (2018.10.15)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.4.4->qiskit) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.4.4->qiskit) (1.23)
# Collecting ntlm-auth>=1.0.2
#   Downloading https://files.pythonhosted.org/packages/50/09/5e397eb18685b14fd8b209e26cdb4fa6451c82c1bcc651fef05fa73e7b27/ntlm_auth-1.4.0-py2.py3-none-any.whl
# Requirement already satisfied: cryptography>=1.3 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.4.4->qiskit) (2.3.1)
# Collecting docloud>=1.0.375
#   Downloading https://files.pythonhosted.org/packages/89/1c/fcb7ea86ae5cb7137a22f00bcaa785de2d102bd4a2b16383ec4a877a835b/docloud-1.0.375.tar.gz
# Requirement already satisfied: python-dateutil in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from quandl->qiskit-aqua==0.6.1->qiskit) (2.8.1)
# Requirement already satisfied: more-itertools in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from quandl->qiskit-aqua==0.6.1->qiskit) (4.3.0)
# Requirement already satisfied: pandas>=0.14 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from quandl->qiskit-aqua==0.6.1->qiskit) (0.23.4)
# Collecting inflection>=0.3.1
#   Downloading https://files.pythonhosted.org/packages/d5/35/a6eb45b4e2356fe688b21570864d4aa0d0a880ce387defe9c589112077f8/inflection-0.3.1.tar.gz
# Requirement already satisfied: asn1crypto>=0.21.0 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.4.4->qiskit) (0.24.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.7 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.4.4->qiskit) (1.11.5)
# Requirement already satisfied: pytz>=2011k in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from pandas>=0.14->quandl->qiskit-aqua==0.6.1->qiskit) (2019.3)
# Requirement already satisfied: pycparser in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from cffi!=1.11.3,>=1.7->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.4.4->qiskit) (2.19)
# Building wheels for collected packages: qiskit, marshmallow-polyfield, docplex, fastdtw, dlx, docloud, inflection
#   Building wheel for qiskit (setup.py) ... done
#   Created wheel for qiskit: filename=qiskit-0.14.0-cp36-none-any.whl size=2494 sha256=dc5fe393f47a7f88ef4c3357ff0c425d36cd773db66898ca56b942b4ad1555c3
#   Stored in directory: /home/nbuser/.cache/pip/wheels/78/56/d2/194c8ea4c20e67c474027da76aa9df2ad5564218bc33073fbd
#   Building wheel for marshmallow-polyfield (setup.py) ... done
#   Created wheel for marshmallow-polyfield: filename=marshmallow_polyfield-5.7-cp36-none-any.whl size=6766 sha256=c12c1bb7376f50eefaa8310a85662e12b4c6ee2ac227aed3537ae6186c107c9f
#   Stored in directory: /home/nbuser/.cache/pip/wheels/68/f5/09/1dcfa8613b095bb326caadfb4b111d7fc945875948b75f5c14
#   Building wheel for docplex (setup.py) ... done
#   Created wheel for docplex: filename=docplex-2.12.182-cp36-none-any.whl size=632305 sha256=39f2891cbbad975f05b21e291efffe9b571478c7a2db59602f29d3c7c18f3119
#   Stored in directory: /home/nbuser/.cache/pip/wheels/9b/ef/71/204f676be3eae44c121c5b779077bd06f573d86cc6524aecc8
#   Building wheel for fastdtw (setup.py) ... done
#   Created wheel for fastdtw: filename=fastdtw-0.3.4-cp36-cp36m-linux_x86_64.whl size=400155 sha256=42bf5ad5e0f8657d8c4dd93507f6e5fadfb7a1ab490fbb5e05bbb25cdb720999
#   Stored in directory: /home/nbuser/.cache/pip/wheels/7e/95/df/935f19af51d6ab63d416c103c0d6eae7048a8c2ecb00a1497f
#   Building wheel for dlx (setup.py) ... done
#   Created wheel for dlx: filename=dlx-1.0.4-cp36-none-any.whl size=6892 sha256=3cf5b2290626274e50c0ba6a3c1ea5ddeb9751b57a9fa16735e86c9b93da371f
#   Stored in directory: /home/nbuser/.cache/pip/wheels/bb/ba/15/fdd0deb104df3254912998150ba9245668db06b00af5912d1a
#   Building wheel for docloud (setup.py) ... done
#   Created wheel for docloud: filename=docloud-1.0.375-cp36-none-any.whl size=16365 sha256=beceac1eab3a26a89523b9c3208fb6b8e177e54c19e2b328a86515c2e7ce7404
#   Stored in directory: /home/nbuser/.cache/pip/wheels/4e/24/19/9b0e57545d7543ecec35c5faff78c058bf0c2506369c8b1d31
#   Building wheel for inflection (setup.py) ... done
#   Created wheel for inflection: filename=inflection-0.3.1-cp36-none-any.whl size=6852 sha256=11332430617c39869b52b4a671215c7eddaecfd41bf31892bcd15aa0d693bedf
#   Stored in directory: /home/nbuser/.cache/pip/wheels/9f/5a/d3/6fc3bf6516d2a3eb7e18f9f28b472110b59325f3f258fe9211
# Successfully built qiskit marshmallow-polyfield docplex fastdtw dlx docloud inflection
# Installing collected packages: marshmallow, marshmallow-polyfield, qiskit-terra, qiskit-aer, websockets, nest-asyncio, ntlm-auth, requests-ntlm, qiskit-ibmq-provider, qiskit-ignis, docloud, docplex, fastdtw, dlx, cvxopt, pyscf, inflection, quandl, qiskit-aqua, qiskit
# Successfully installed cvxopt-1.2.3 dlx-1.0.4 docloud-1.0.375 docplex-2.12.182 fastdtw-0.3.4 inflection-0.3.1 marshmallow-3.3.0 marshmallow-polyfield-5.7 nest-asyncio-1.2.1 ntlm-auth-1.4.0 pyscf-1.7.0 qiskit-0.14.0 qiskit-aer-0.3.4 qiskit-aqua-0.6.1 qiskit-ibmq-provider-0.4.4 qiskit-ignis-0.2.0 qiskit-terra-0.11.0 quandl-3.5.0 requests-ntlm-1.1.0 websockets-7.0

# %%
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
from qiskit import execute
from qiskit import BasicAer
from qiskit.tools.visualization import plot_histogram, plot_bloch_multivector

import numpy as np
π = np.pi

backend = BasicAer.get_backend('qasm_simulator')

q = QuantumRegister(1)
c = ClassicalRegister(1)
circuit = QuantumCircuit(q, c)

# %%
backend_statevector = BasicAer.get_backend('statevector_simulator')
circuit = QuantumCircuit(q, c)
circuit.iden(q[0])
job = execute(circuit, backend_statevector)
plot_bloch_multivector(job.result().get_statevector(circuit))

# %%
backend_statevector = BasicAer.get_backend('statevector_simulator')
circuit = QuantumCircuit(q, c)

circuit.rx(π, q[0])
#circuit.ry(π, q[0])

job = execute(circuit, backend_statevector)
plot_bloch_multivector(job.result().get_statevector(circuit))
